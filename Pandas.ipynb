# %% [markdown]
# <h1>Pandas and matplotlib</h1>
# Pandas is arguably the most used library in data science and most visualisations in python are made using matplotlib. They are also incredibly important to Machine Learning as they allow one to explore the data (and formulate the questions based on it) and also CLEAN/PREPARE the data. It is not an exageration saying that 80-90% of the work done by a Data Scientist is cleaning data.
#
# [pandas](https://pandas.pydata.org/) is a powerful library that allows one to work with data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/e1/1e/d708cda584a2d70e6d3c930d102d07ee3d65bec3b2861f416b086cc518a8/pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/a3/fb/52b62131e21b24ee297e4e95ed41eba29647dad0e0051a92bb66b43c70ff/tzdata-2023.4-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 8.5 MB/s eta 0:00:0000:01:00:01
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 4.3 MB/s eta 0:00:00:00:0100:01
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 4.1 MB/s eta 0:00:00:00:01
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.0 pytz-2023.3.post1 tzdata-2023.4
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To open our dataset let us use [pd.read csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
pokemon_df = pd.read_csv('Datasets/Pokemon.csv', sep=',')

# %% [markdown]
# Question: df stands for dataframe but what is a dataframe?

# %% [markdown]
# Question: how do we print the dataframe? When is that convenient?

# %%
print(pokemon_df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Being able to see the entirety of the data on the screen is a double edged sword. In one hand the human working on a given dataset can be there visually inspecting the dataset all the time. On the other hand this process of merely displaying the data can quickly become a burden to the processing time. It is then more practical to use a different approach when dealing with large datasets.<br>
#
# In this sense there are a few tools we can use to inspect the data for example [head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) and [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html).

# %%
# Displaying the first 5 rows of the dataframe.
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Displaying the bottom 5 rows of the dataframe.
pokemon_df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# Another very powerful tool is [describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# Question: what are we seeing above? How is that useful? How is that NOT useful?

# %% [markdown]
# It is also possible to query specific aspects of each individual column. To select only a column it is similar to getting a specific item of a dictionary,

# %%
# Getting only the items that are in the HP column.
pokemon_df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
pokemon_df.HP
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
# A list of columns can also be selected.
pokemon_df[['HP','Attack','Speed']]
# Out:
#      HP  Attack  Speed
# 0    45      49     45
# 1    60      62     60
# 2    80      82     80
# 3    80     100     80
# 4    39      52     65
# ..   ..     ...    ...
# 795  50     100     50
# 796  50     160    110
# 797  80     110     70
# 798  80     160     80
# 799  80     110     70
#
# [800 rows x 3 columns]

# %% [markdown]
# To get to know all keys of the dataframe (or for getting something you can quick copy and paste) you can use

# %%
# This also works on dictionaries!
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# For non-numerical columns other tools are more appropriated to understand the value distribution, such as

# %%
# This shows all the unique entries in the dataset for that column.
pokemon_df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# This will count how much incidence of a given unique entry is seen on the dataframe.
pokemon_df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# Exercises: how many pokemons does each different generation have? Also, how many legendary pokemons are there in total?

# %%
pokemon_df['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
pokemon_df[0:20]
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 14  11                    Metapod    Bug     NaN    205  50      20       55
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 16  13                     Weedle    Bug  Poison    195  40      35       30
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
# 18  15                   Beedrill    Bug  Poison    395  65      90       40
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# 15       90       80     70           1      False
# 16       20       20     50           1      False
# 17       25       25     35           1      False
# 18       45       80     75           1      False
# 19       15       80    145           1      False

# %%
pokemon_df['Legendary'].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
pwd
# Out:
# '/Users/esthersaul/Downloads/python module /Python-Module-fork'

# %% [markdown]
# This is how we save our dataframe.

# %%
#Exporting data.
pokemon_df.to_csv('filename.csv', sep=',')

# %% [markdown]
# Describing the dataset.

# %%
# Getting the description.
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# Question: what is all this information above?

# %%
# Combining methods.
pokemon_df.describe().to_csv('description.csv')

# %% [markdown]
# Now to operate over a single column the operands we've seen so far work,

# %%
pokemon_df['HP'] + 5
# Out:
# 0      50
# 1      65
# 2      85
# 3      85
# 4      44
#        ..
# 795    55
# 796    55
# 797    85
# 798    85
# 799    85
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# Question: Did the operation above changed the actual values in the dataframe?

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Creating a new column in a dataframe is quite simple,

# %%
pokemon_df['Irrelevant'] = np.nan
pokemon_df['HP+100'] = pokemon_df['HP'] + 100

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100
# 0         65       65     45           1      False         NaN     145
# 1         80       80     60           1      False         NaN     160
# 2        100      100     80           1      False         NaN     180
# 3        122      120     80           1      False         NaN     180
# 4         60       50     65           1      False         NaN     139
# ..       ...      ...    ...         ...        ...         ...     ...
# 795      100      150     50           6       True         NaN     150
# 796      160      110    110           6       True         NaN     150
# 797      150      130     70           6       True         NaN     180
# 798      170      130     80           6       True         NaN     180
# 799      130       90     70           6       True         NaN     180
#
# [800 rows x 15 columns]

# %%
pokemon_df['Atk+Def+HP'] = pokemon_df['Attack'] + pokemon_df['Defense'] + pokemon_df['HP']

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 0       65       65     45           1      False         NaN     145
# 1       80       80     60           1      False         NaN     160
# 2      100      100     80           1      False         NaN     180
# 3      122      120     80           1      False         NaN     180
# 4       60       50     65           1      False         NaN     139
#
#    Atk+Def+HP
# 0         143
# 1         185
# 2         245
# 3         303
# 4         134

# %%
pokemon_df.HP
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# As it is dropping those columns with [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
# Getting the column names for a copy paste
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Irrelevant',
#        'HP+100', 'Atk+Def+HP'],
#       dtype='object')

# %%
# Listing the columns to drop. 
# axis = 1 means we're dropping it column-wise.
pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP
# 0         65       65     45           1      False         143
# 1         80       80     60           1      False         185
# 2        100      100     80           1      False         245
# 3        122      120     80           1      False         303
# 4         60       50     65           1      False         134
# ..       ...      ...    ...         ...        ...         ...
# 795      100      150     50           6       True         300
# 796      160      110    110           6       True         320
# 797      150      130     70           6       True         250
# 798      170      130     80           6       True         300
# 799      130       90     70           6       True         310
#
# [800 rows x 14 columns]

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 0       65       65     45           1      False         NaN     145
# 1       80       80     60           1      False         NaN     160
# 2      100      100     80           1      False         NaN     180
# 3      122      120     80           1      False         NaN     180
# 4       60       50     65           1      False         NaN     139
#
#    Atk+Def+HP
# 0         143
# 1         185
# 2         245
# 3         303
# 4         134

# %%
# Modifying a specific datapoint.
pokemon_df.at[0,'Irrelevant'] = 10

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 0         65       65     45           1      False        10.0     145
# 1         80       80     60           1      False         NaN     160
# 2        100      100     80           1      False         NaN     180
# 3        122      120     80           1      False         NaN     180
# 4         60       50     65           1      False         NaN     139
# ..       ...      ...    ...         ...        ...         ...     ...
# 795      100      150     50           6       True         NaN     150
# 796      160      110    110           6       True         NaN     150
# 797      150      130     70           6       True         NaN     180
# 798      170      130     80           6       True         NaN     180
# 799      130       90     70           6       True         NaN     180
#
#      Atk+Def+HP
# 0           143
# 1           185
# 2           245
# 3           303
# 4           134
# ..          ...
# 795         300
# 796         320
# 797         250
# 798         300
# 799         310
#
# [800 rows x 16 columns]

# %% [markdown]
# Question: why are the columns still there then? how do we actually get rid of them?

# %% [markdown]
# Exercise: create a new column where the Attack of each pokemon is divided by the maximum value on the attack column, and a new column containing the division of the attack and defense stats.

# %%
pokemon_df['Atk/Max'] = pokemon_df['Attack'] / max(pokemon_df['Attack'])
pokemon_df['Atk/Def'] = pokemon_df['Attack'] / max(pokemon_df['Defense'])

# %%
np.max(pokemon_df['Attack'])
# Out:
# 190

# %%
pokemon_df['Attack'].max()
# Out:
# 190

# %%
pokemon_df['Atk/Max'] = pokemon_df['Attack'] / 190

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 0       65       65     45           1      False        10.0     145
# 1       80       80     60           1      False         NaN     160
# 2      100      100     80           1      False         NaN     180
# 3      122      120     80           1      False         NaN     180
# 4       60       50     65           1      False         NaN     139
#
#    Atk+Def+HP   Atk/Max   Atk/Def
# 0         143  0.257895  0.213043
# 1         185  0.326316  0.269565
# 2         245  0.431579  0.356522
# 3         303  0.526316  0.434783
# 4         134  0.273684  0.226087

# %% [markdown]
# Filtering is also a process where a data scientist can spend countless hours in. Using pandas the process is also quite simple.

# %%
# Showcase the pokemons with HP larger than 80.
pokemon_df[pokemon_df['HP'] > 80]
# Out:
#        #                 Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 22    18              Pidgeot  Normal  Flying    479   83      80       75
# 23    18  PidgeotMega Pidgeot  Normal  Flying    579   83      80       80
# 36    31            Nidoqueen  Poison  Ground    505   90      92       87
# 39    34             Nidoking  Poison  Ground    505   81     102       77
# 41    36             Clefable   Fairy     NaN    483   95      70       73
# ..   ...                  ...     ...     ...    ...  ...     ...      ...
# 789  713              Avalugg     Ice     NaN    514   95     117      184
# 791  715              Noivern  Flying  Dragon    535   85      70       80
# 792  716              Xerneas   Fairy     NaN    680  126     131       95
# 793  717              Yveltal    Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 22        70       70    101           1      False         NaN     183
# 23       135       80    121           1      False         NaN     183
# 36        75       85     76           1      False         NaN     190
# 39        85       75     85           1      False         NaN     181
# 41        95       90     60           1      False         NaN     195
# ..       ...      ...    ...         ...        ...         ...     ...
# 789       44       46     28           6      False         NaN     195
# 791       97       80    123           6      False         NaN     185
# 792      131       98     99           6       True         NaN     226
# 793      131       98     99           6       True         NaN     226
# 794       81       95     95           6       True         NaN     208
#
#      Atk+Def+HP   Atk/Max   Atk/Def
# 22          238  0.421053  0.347826
# 23          243  0.421053  0.347826
# 36          269  0.484211  0.400000
# 39          260  0.536842  0.443478
# 41          238  0.368421  0.304348
# ..          ...       ...       ...
# 789         396  0.615789  0.508696
# 791         235  0.368421  0.304348
# 792         352  0.689474  0.569565
# 793         352  0.689474  0.569565
# 794         329  0.526316  0.434783
#
# [193 rows x 18 columns]

# %%
len(pokemon_df[pokemon_df['HP'] > 80])
# Out:
# 193

# %%
# Notice that the condition doesn't need to be numerical.
pokemon_df[pokemon_df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# 147  136                    Flareon   Fire       NaN    525   65     130
# 158  146                    Moltres   Fire    Flying    580   90     100
# 169  155                  Cyndaquil   Fire       NaN    309   39      52
# 170  156                    Quilava   Fire       NaN    405   58      64
# 171  157                 Typhlosion   Fire       NaN    534   78      84
# 236  218                     Slugma   Fire       NaN    250   40      40
# 237  219                   Magcargo   Fire      Rock    410   50      50
# 259  240                      Magby   Fire       NaN    365   45      75
# 263  244                      Entei   Fire       NaN    580  115     115
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 276  255                    Torchic   Fire       NaN    310   45      60
# 277  256                  Combusken   Fire  Fighting    405   60      85
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 352  322                      Numel   Fire    Ground    305   60      60
# 353  323                   Camerupt   Fire    Ground    460   70     100
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 355  324                    Torkoal   Fire       NaN    470   70      85
# 435  390                   Chimchar   Fire       NaN    309   44      58
# 436  391                   Monferno   Fire  Fighting    405   64      78
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 518  467                  Magmortar   Fire       NaN    540   75      95
# 542  485                    Heatran   Fire     Steel    600   91      90
# 557  498                      Tepig   Fire       NaN    308   65      63
# 558  499                    Pignite   Fire  Fighting    418   90      93
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 572  513                    Pansear   Fire       NaN    316   50      53
# 573  514                   Simisear   Fire       NaN    498   75      98
# 614  554                   Darumaka   Fire       NaN    315   70      90
# 615  555    DarmanitanStandard Mode   Fire       NaN    480  105     140
# 616  555         DarmanitanZen Mode   Fire   Psychic    540  105      30
# 692  631                    Heatmor   Fire       NaN    484   85      97
# 721  653                   Fennekin   Fire       NaN    307   40      45
# 722  654                    Braixen   Fire       NaN    409   59      59
# 723  655                    Delphox   Fire   Psychic    534   75      69
# 730  662                Fletchinder   Fire    Flying    382   62      73
# 731  663                 Talonflame   Fire    Flying    499   78      81
# 735  667                     Litleo   Fire    Normal    369   62      50
# 736  668                     Pyroar   Fire    Normal    507   86      68
# 799  721                  Volcanion   Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  \
# 4         43       60       50     65           1      False         NaN
# 5         58       80       65     80           1      False         NaN
# 6         78      109       85    100           1      False         NaN
# 7        111      130       85    100           1      False         NaN
# 8         78      159      115    100           1      False         NaN
# 42        40       50       65     65           1      False         NaN
# 43        75       81      100    100           1      False         NaN
# 63        45       70       50     60           1      False         NaN
# 64        80      100       80     95           1      False         NaN
# 83        55       65       65     90           1      False         NaN
# 84        70       80       80    105           1      False         NaN
# 135       57      100       85     93           1      False         NaN
# 147       60       95      110     65           1      False         NaN
# 158       90      125       85     90           1       True         NaN
# 169       43       60       50     65           2      False         NaN
# 170       58       80       65     80           2      False         NaN
# 171       78      109       85    100           2      False         NaN
# 236       40       70       40     20           2      False         NaN
# 237      120       80       80     30           2      False         NaN
# 259       37       70       55     83           2      False         NaN
# 263       85       90       75    100           2       True         NaN
# 270       90      110      154     90           2       True         NaN
# 276       40       70       50     45           3      False         NaN
# 277       60       85       60     55           3      False         NaN
# 278       70      110       70     80           3      False         NaN
# 279       80      130       80    100           3      False         NaN
# 352       40       65       45     35           3      False         NaN
# 353       70      105       75     40           3      False         NaN
# 354      100      145      105     20           3      False         NaN
# 355      140       85       70     20           3      False         NaN
# 435       44       58       44     61           4      False         NaN
# 436       52       78       52     81           4      False         NaN
# 437       71      104       71    108           4      False         NaN
# 518       67      125       95     83           4      False         NaN
# 542      106      130      106     77           4       True         NaN
# 557       45       45       45     45           5      False         NaN
# 558       55       70       55     55           5      False         NaN
# 559       65      100       65     65           5      False         NaN
# 572       48       53       48     64           5      False         NaN
# 573       63       98       63    101           5      False         NaN
# 614       45       15       45     50           5      False         NaN
# 615       55       30       55     95           5      False         NaN
# 616      105      140      105     55           5      False         NaN
# 692       66      105       66     65           5      False         NaN
# 721       40       62       60     60           6      False         NaN
# 722       58       90       70     73           6      False         NaN
# 723       72      114      100    104           6      False         NaN
# 730       55       56       52     84           6      False         NaN
# 731       71       74       69    126           6      False         NaN
# 735       58       73       54     72           6      False         NaN
# 736       72      109       66    106           6      False         NaN
# 799      120      130       90     70           6       True         NaN
#
#      HP+100  Atk+Def+HP   Atk/Max   Atk/Def
# 4       139         134  0.273684  0.226087
# 5       158         180  0.336842  0.278261
# 6       178         240  0.442105  0.365217
# 7       178         319  0.684211  0.565217
# 8       178         260  0.547368  0.452174
# 42      138         119  0.215789  0.178261
# 43      173         224  0.400000  0.330435
# 63      155         170  0.368421  0.304348
# 64      190         280  0.578947  0.478261
# 83      150         190  0.447368  0.369565
# 84      165         235  0.526316  0.434783
# 135     165         217  0.500000  0.413043
# 147     165         255  0.684211  0.565217
# 158     190         280  0.526316  0.434783
# 169     139         134  0.273684  0.226087
# 170     158         180  0.336842  0.278261
# 171     178         240  0.442105  0.365217
# 236     140         120  0.210526  0.173913
# 237     150         220  0.263158  0.217391
# 259     145         157  0.394737  0.326087
# 263     215         315  0.605263  0.500000
# 270     206         326  0.684211  0.565217
# 276     145         145  0.315789  0.260870
# 277     160         205  0.447368  0.369565
# 278     180         270  0.631579  0.521739
# 279     180         320  0.842105  0.695652
# 352     160         160  0.315789  0.260870
# 353     170         240  0.526316  0.434783
# 354     170         290  0.631579  0.521739
# 355     170         295  0.447368  0.369565
# 435     144         146  0.305263  0.252174
# 436     164         194  0.410526  0.339130
# 437     176         251  0.547368  0.452174
# 518     175         237  0.500000  0.413043
# 542     191         287  0.473684  0.391304
# 557     165         173  0.331579  0.273913
# 558     190         238  0.489474  0.404348
# 559     210         298  0.647368  0.534783
# 572     150         151  0.278947  0.230435
# 573     175         236  0.515789  0.426087
# 614     170         205  0.473684  0.391304
# 615     205         300  0.736842  0.608696
# 616     205         240  0.157895  0.130435
# 692     185         248  0.510526  0.421739
# 721     140         125  0.236842  0.195652
# 722     159         176  0.310526  0.256522
# 723     175         216  0.363158  0.300000
# 730     162         190  0.384211  0.317391
# 731     178         230  0.426316  0.352174
# 735     162         170  0.263158  0.217391
# 736     186         226  0.357895  0.295652
# 799     180         310  0.578947  0.478261

# %%
# Notice that the condition doesn't need to be numerical.
pokemon_df[(pokemon_df['Type 1'] == 'Ice')&(pokemon_df['Type 2'] == 'Psychic')]
# Out:
#        #      Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 133  124      Jynx    Ice  Psychic    455  65      50       35      115
# 257  238  Smoochum    Ice  Psychic    305  45      30       15       85
#
#      Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  Atk+Def+HP  \
# 133       95     95           1      False         NaN     165         150
# 257       65     65           2      False         NaN     145          90
#
#       Atk/Max   Atk/Def
# 133  0.263158  0.217391
# 257  0.157895  0.130435

# %% [markdown]
# Exercise: how do we measure how many entries satisfy the stated condition above? I.e., what is the length of the dataframe. [hint](https://www.w3schools.com/python/gloss_python_string_length.asp)

# %%
len(pokemon_df[(pokemon_df['Type 1'] == 'Ice')&(pokemon_df['Type 2'] == 'Psychic')])
# Out:
# 2

# %% [markdown]
# Examples on how to sort the dataframe.

# %%
# Use this to show the largest imbalances on attack/defense.
pokemon_df.sort_values(by=['Atk/Def'])[0:10]
# Out:
#        #      Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 488  440   Happiny   Normal     NaN    220  100       5        5       15
# 121  113   Chansey   Normal     NaN    450  250       5        5       35
# 230  213   Shuckle      Bug    Rock    505   20      10      230       10
# 261  242   Blissey   Normal     NaN    540  255      10       10       75
# 139  129  Magikarp    Water     NaN    200   20      10       55       15
# 381  349    Feebas    Water     NaN    200   20      15       20       10
# 68    63      Abra  Psychic     NaN    310   25      20       15      105
# 508  458   Mantyke    Water  Flying    345   45      20       50       60
# 179  165    Ledyba      Bug  Flying    265   40      20       30       40
# 189  175    Togepi    Fairy     NaN    245   35      20       65       40
#
#      Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  Atk+Def+HP  \
# 488       65     30           4      False         NaN     200         110
# 121      105     50           1      False         NaN     350         260
# 230      230      5           2      False         NaN     120         260
# 261      135     55           2      False         NaN     355         275
# 139       20     80           1      False         NaN     120          85
# 381       55     80           3      False         NaN     120          55
# 68        55     90           1      False         NaN     125          60
# 508      120     50           4      False         NaN     145         115
# 179       80     55           2      False         NaN     140          90
# 189       65     20           2      False         NaN     135         120
#
#       Atk/Max   Atk/Def
# 488  0.026316  0.021739
# 121  0.026316  0.021739
# 230  0.052632  0.043478
# 261  0.052632  0.043478
# 139  0.052632  0.043478
# 381  0.078947  0.065217
# 68   0.105263  0.086957
# 508  0.105263  0.086957
# 179  0.105263  0.086957
# 189  0.105263  0.086957

# %%
pokemon_df.sort_values(by=['Atk/Def'], ascending=False)[0:10]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 711  646       KyuremBlack Kyurem   Dragon       Ice    700  125     170
# 494  445    GarchompMega Garchomp   Dragon    Ground    700  108     170
# 527  475      GalladeMega Gallade  Psychic  Fighting    618   68     165
# 387  354      BanetteMega Banette    Ghost       NaN    555   64     165
# 454  409                Rampardos     Rock       NaN    495   97     165
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  \
# 163      100      154      100    130           1       True         NaN
# 232      115       40      105     75           2      False         NaN
# 424      160      150       90     90           3       True         NaN
# 426      100      180      100    115           3       True         NaN
# 429       20      180       20    150           3       True         NaN
# 711      100      120       90     95           5       True         NaN
# 494      115      120       95     92           4      False         NaN
# 527       95       65      115    110           4      False         NaN
# 387       75       93       83     75           3      False         NaN
# 454       60       65       50     58           4      False         NaN
#
#      HP+100  Atk+Def+HP   Atk/Max   Atk/Def
# 163     206         396  1.000000  0.826087
# 232     180         380  0.973684  0.804348
# 424     200         440  0.947368  0.782609
# 426     205         385  0.947368  0.782609
# 429     150         250  0.947368  0.782609
# 711     225         395  0.894737  0.739130
# 494     208         393  0.894737  0.739130
# 527     168         328  0.868421  0.717391
# 387     164         304  0.868421  0.717391
# 454     197         322  0.868421  0.717391

# %%
pokemon_df.sort_values(by=['Attack'], ascending=False)[0:10]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 711  646       KyuremBlack Kyurem   Dragon       Ice    700  125     170
# 494  445    GarchompMega Garchomp   Dragon    Ground    700  108     170
# 527  475      GalladeMega Gallade  Psychic  Fighting    618   68     165
# 387  354      BanetteMega Banette    Ghost       NaN    555   64     165
# 454  409                Rampardos     Rock       NaN    495   97     165
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  \
# 163      100      154      100    130           1       True         NaN
# 232      115       40      105     75           2      False         NaN
# 424      160      150       90     90           3       True         NaN
# 426      100      180      100    115           3       True         NaN
# 429       20      180       20    150           3       True         NaN
# 711      100      120       90     95           5       True         NaN
# 494      115      120       95     92           4      False         NaN
# 527       95       65      115    110           4      False         NaN
# 387       75       93       83     75           3      False         NaN
# 454       60       65       50     58           4      False         NaN
#
#      HP+100  Atk+Def+HP   Atk/Max   Atk/Def
# 163     206         396  1.000000  0.826087
# 232     180         380  0.973684  0.804348
# 424     200         440  0.947368  0.782609
# 426     205         385  0.947368  0.782609
# 429     150         250  0.947368  0.782609
# 711     225         395  0.894737  0.739130
# 494     208         393  0.894737  0.739130
# 527     168         328  0.868421  0.717391
# 387     164         304  0.868421  0.717391
# 454     197         322  0.868421  0.717391

# %% [markdown]
# Exercise: how many pokemons don't have a second type? [hint](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)
#
# What fraction of the dataset do they represent?

# %%
pokemon_df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# Irrelevant    799
# HP+100          0
# Atk+Def+HP      0
# Atk/Max         0
# Atk/Def         0
# dtype: int64

# %%
pokemon_df['Type 2'].isnull().sum() / len(pokemon_df)
# Out:
# 0.4825

# %% [markdown]
# Now numbers can be quite confusing and their significance is limited when context or comparissons are not offered. In this sense pandas dataframes also contain many built-in functions that can help you. For example:

# %%
pokemon_df['Attack'].describe()
# Out:
# count    800.000000
# mean      79.001250
# std       32.457366
# min        5.000000
# 25%       55.000000
# 50%       75.000000
# 75%      100.000000
# max      190.000000
# Name: Attack, dtype: float64

# %%
pokemon_df.hist()
# Out:
# array([[<Axes: title={'center': '#'}>, <Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'HP'}>,
#         <Axes: title={'center': 'Attack'}>],
#        [<Axes: title={'center': 'Defense'}>,
#         <Axes: title={'center': 'Sp. Atk'}>,
#         <Axes: title={'center': 'Sp. Def'}>,
#         <Axes: title={'center': 'Speed'}>],
#        [<Axes: title={'center': 'Generation'}>,
#         <Axes: title={'center': 'Irrelevant'}>,
#         <Axes: title={'center': 'HP+100'}>,
#         <Axes: title={'center': 'Atk+Def+HP'}>],
#        [<Axes: title={'center': 'Atk/Max'}>,
#         <Axes: title={'center': 'Atk/Def'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Exploring the built in histogram method.

# %%
# This plots the histogram of the attack column
pokemon_df.hist('Attack')
# Out:
# array([[<Axes: title={'center': 'Attack'}>]], dtype=object)

# %% [markdown]
# Exploring a line plot.

# %%
pokemon_df['Attack'].plot()
# Out:
# <Axes: >

# %%
# Plotting the first 20 points only.
pokemon_df['Attack'][0:20].plot()
# Out:
# <Axes: >

# %% [markdown]
# Question, is this plot appropriate for this data?
#
# Now look at the following scatter plot.

# %%
pokemon_df.plot.scatter(x='#',y='Attack')
# Out:
# <Axes: xlabel='#', ylabel='Attack'>

# %% [markdown]
# What's the difference between a plot and a scatter plot?

# %%
pokemon_df.plot.scatter(x='Attack',y='Defense')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# What relevant information can we extract from this sort of plot? what is the use of scattering a column agains't the other?
#
# Further modifying figures with matplotlib.

# %%
# Create figure object and defining axes.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

fig.suptitle('This is the title!')

# Above all, notice the ax = ax[0,0].
pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0,0])
pokemon_df.plot.scatter(x='Attack',y='Defense', ax=axes[1,0])
pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0,1])
pokemon_df.plot.scatter(x='Attack',y='Defense', s=1, ax=axes[1,1])
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# Exercise: for every pokemon type make a scatter plot of attack vs defense (and do colour them differently).

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

for key in pokemon_df['Type 1'].unique():
    print(key)

    axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == key]['Attack'],
                 y=pokemon_df[pokemon_df['Type 1'] == key]['Defense']
                 s = 5,
                 label=key)
    
    plt.legend()
# Out:
#   Cell In[85], line 7
#     y=pokemon_df[pokemon_df['Type 1'] == key]['Defense']
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# My solution.
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

for key in pokemon_df['Type 1'].unique():
    print(key)

    axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == key]['Attack'],
                 y=pokemon_df[pokemon_df['Type 1'] == key]['Defense'],
                s=5,
                label=key)
    
    plt.legend()
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Defense'],
             s=5, 
             color='red')

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Defense'],
             s=5, 
             color='green')


#pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0])
#pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, ax=axes[0])

# %% [markdown]
# A complete guide on the methods that can be acessed in a dataframe object can be found [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html).
#
# Exercise: now do the histogram of the HP, defense and speed columns.

# %%
pokemon_df.hist('HP')
pokemon_df.hist('Defense')
pokemon_df.hist('Speed')
# Out:
# array([[<Axes: title={'center': 'Speed'}>]], dtype=object)

# %%
pokemon_df['HP'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(12,6))
pokemon_df['HP'].plot.hist(ax=axes[0], bins=50, alpha=0.5, color='red')
axes[0].set_title('HP')

pokemon_df['Defense'].plot.hist(ax=axes[1], bins=50, alpha=.5, color='red')
axes[1].set_title('Defense')
pokemon_df['Attack'].plot.hist(ax=axes[1], bins=50, alpha=.5, color='blue')
axes[1].set_title('Attack')

pokemon_df['Speed'].plot.hist(ax=axes[2], bins=50, alpha=0.5, color='green')
axes[2].set_title('Speed')

axes[1].set_ylabel('')
axes[2].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(12,6))
pokemon_df['HP'].plot.hist(ax=axes[0], bins=50, alpha=0.5, color='red')
axes[0].set_title('HP')

pokemon_df['Defense'].plot.hist(ax=axes[1], bins=50, alpha=0.5, color='grey')
axes[1].set_title('Defense')

pokemon_df['Speed'].plot.hist(ax=axes[2], bins=50, alpha=0.5, color='green')
axes[2].set_title('Speed')
# Out:
# Text(0.5, 1.0, 'Speed')

# %% [markdown]
# Numpy can also be used in conjunction with pandas to study the dataframes. For example

# %%
# Returns the maximum value of the pokemons HP.
np.max(pokemon_df['HP'])
# Out:
# 255

# %%
# Returns the mean value of the pokemons attack.
np.mean(pokemon_df['Attack'])
# Out:
# 79.00125

# %% [markdown]
# Exercise: Find out how many pokemons have their Attack stat above the average value for the entire set.

# %% [markdown]
# Another thing that is very common to find is missing entries and there are different stragies that can be employed (for [example](https://pandas.pydata.org/docs/user_guide/missing_data.html)). Using [dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html) we can drop all the rows that have a missing value,

# %%
pokemon_df.dropna()
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary  Irrelevant  HP+100  Atk+Def+HP   Atk/Max  \
# 0     45           1      False        10.0     145         143  0.257895
#
#     Atk/Def
# 0  0.213043

# %% [markdown]
# Why all the dataframe was wipped out?

# %% [markdown]
# Columns can be individually dropped using [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Irrelevant',
#        'HP+100', 'Atk+Def+HP', 'Atk/Max', 'Atk/Def'],
#       dtype='object')

# %%
# For example:
pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP   Atk/Max  \
# 0         65       65     45           1      False         143  0.257895
# 1         80       80     60           1      False         185  0.326316
# 2        100      100     80           1      False         245  0.431579
# 3        122      120     80           1      False         303  0.526316
# 4         60       50     65           1      False         134  0.273684
# ..       ...      ...    ...         ...        ...         ...       ...
# 795      100      150     50           6       True         300  0.526316
# 796      160      110    110           6       True         320  0.842105
# 797      150      130     70           6       True         250  0.578947
# 798      170      130     80           6       True         300  0.842105
# 799      130       90     70           6       True         310  0.578947
#
#       Atk/Def
# 0    0.213043
# 1    0.269565
# 2    0.356522
# 3    0.434783
# 4    0.226087
# ..        ...
# 795  0.434783
# 796  0.695652
# 797  0.478261
# 798  0.695652
# 799  0.478261
#
# [800 rows x 16 columns]

# %%
pokemon_df = pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
# Now the NANs are not in every row anymore! see the result.
pokemon_df.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP   Atk/Max  \
# 0         65       65     45           1      False         143  0.257895
# 1         80       80     60           1      False         185  0.326316
# 2        100      100     80           1      False         245  0.431579
# 3        122      120     80           1      False         303  0.526316
# 6        109       85    100           1      False         240  0.442105
# ..       ...      ...    ...         ...        ...         ...       ...
# 795      100      150     50           6       True         300  0.526316
# 796      160      110    110           6       True         320  0.842105
# 797      150      130     70           6       True         250  0.578947
# 798      170      130     80           6       True         300  0.842105
# 799      130       90     70           6       True         310  0.578947
#
#       Atk/Def
# 0    0.213043
# 1    0.269565
# 2    0.356522
# 3    0.434783
# 6    0.365217
# ..        ...
# 795  0.434783
# 796  0.695652
# 797  0.478261
# 798  0.695652
# 799  0.478261
#
# [414 rows x 16 columns]

# %% [markdown]
# Exercise: compare the lengths of the dataframe before and after dropping the missing values.

# %% [markdown]
# Question: When is it appropriated to drop the missing values?

# %% [markdown]
# Exercise: make a pie chart showcasing the distribution of pokemon types.

# %% [markdown]
# Exercise: which is the strongest pokemon?

# %% [markdown]
# Exercise: what is a boxplot?

# %% [markdown]
# Exercise: make a box plot showcasing the different pokemon attacks.

# %% [markdown]
# If you want to dive into pandas and machine learning I recommend using [Kaggle](https://www.kaggle.com/). This platform contains a multitude of interactive tutorials that can facilitate your learning process.

# %%
import seaborn as sns

sns.set()

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Defense'],
             s=1, 
             color='red')
axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Defense'],
             s=1, 
             color='green')

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation  Atk+Def+HP     Atk/Max     Atk/Def
# count  800.000000  800.000000   800.00000  800.000000  800.000000  800.000000
# mean    71.902500   68.277500     3.32375  222.102500    0.415796    0.343484
# std     27.828916   29.060474     1.66129   68.173834    0.170828    0.141119
# min     20.000000    5.000000     1.00000   55.000000    0.026316    0.021739
# 25%     50.000000   45.000000     2.00000  170.000000    0.289474    0.239130
# 50%     70.000000   65.000000     3.00000  222.000000    0.394737    0.326087
# 75%     90.000000   90.000000     5.00000  269.250000    0.526316    0.434783
# max    230.000000  180.000000     6.00000  440.000000    1.000000    0.826087

# %%
sns.boxplot(x=pokemon_df['Attack'])
# Out:
# <Axes: xlabel='Attack'>

# %%
pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# Out:
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# ...
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_85865/2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# array([<Axes: ylabel='Grass'>, <Axes: ylabel='Fire'>,
#        <Axes: ylabel='Water'>, <Axes: ylabel='Bug'>,
#        <Axes: ylabel='Normal'>, <Axes: ylabel='Poison'>,
#        <Axes: ylabel='Electric'>, <Axes: ylabel='Ground'>,
#        <Axes: ylabel='Fairy'>, <Axes: ylabel='Fighting'>,
#        <Axes: ylabel='Psychic'>, <Axes: ylabel='Rock'>,
#        <Axes: ylabel='Ghost'>, <Axes: ylabel='Ice'>,
#        <Axes: ylabel='Dragon'>, <Axes: ylabel='Dark'>,
#        <Axes: ylabel='Steel'>, <Axes: ylabel='Flying'>], dtype=object)
# Error in callback <function _draw_all_if_interactive at 0x11b65e520> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/legend.py:780, in Legend.draw(self, renderer)
#     777     Shadow(self.legendPatch, **self._shadow_props).draw(renderer)
#     779 self.legendPatch.draw(renderer)
# --> 780 self._legend_box.draw(renderer)
#     782 renderer.close_group('legend')
#     783 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/offsetbox.py:415, in OffsetBox.draw(self, renderer)
#     413 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     414     c.set_offset((px + ox, py + oy))
# --> 415     c.draw(renderer)
#     416 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     417 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/offsetbox.py:415, in OffsetBox.draw(self, renderer)
#     413 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     414     c.set_offset((px + ox, py + oy))
# --> 415     c.draw(renderer)
#     416 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     417 self.stale = False
#
#     [... skipping similar frames: _prevent_rasterization.<locals>.draw_wrapper at line 39 (2 times), OffsetBox.draw at line 415 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/offsetbox.py:415, in OffsetBox.draw(self, renderer)
#     413 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     414     c.set_offset((px + ox, py + oy))
# --> 415     c.draw(renderer)
#     416 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     417 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/offsetbox.py:819, in TextArea.draw(self, renderer)
#     817 def draw(self, renderer):
#     818     # docstring inherited
# --> 819     self._text.draw(renderer)
#     820     _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     821     self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/text.py:797, in Text.draw(self, renderer)
#     793             textrenderer.draw_tex(gc, x, y, clean_line,
#     794                                   self._fontproperties, angle,
#     795                                   mtext=mtext)
#     796         else:
# --> 797             textrenderer.draw_text(gc, x, y, clean_line,
#     798                                    self._fontproperties, angle,
#     799                                    ismath=ismath, mtext=mtext)
#     801 gc.restore()
#     802 renderer.close_group('text')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:194, in RendererAgg.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     191 font = self._prepare_font(prop)
#     192 # We pass '0' for angle here, since it will be rotated (in raster
#     193 # space) in the following call to draw_text_image).
# --> 194 font.set_text(s, 0, flags=get_hinting_flag())
#     195 font.draw_glyphs_to_bitmap(
#     196     antialiased=gc.get_antialiased())
#     197 d = font.get_descent() / 64.0
#
# KeyboardInterrupt:

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP   Atk/Max  \
# 0       65       65     45           1      False         143  0.257895
# 1       80       80     60           1      False         185  0.326316
# 2      100      100     80           1      False         245  0.431579
# 3      122      120     80           1      False         303  0.526316
# 4       60       50     65           1      False         134  0.273684
#
#     Atk/Def
# 0  0.213043
# 1  0.269565
# 2  0.356522
# 3  0.434783
# 4  0.226087

# %%
pokemon_df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
pokemon_df['Type 1'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

pokemon_df['Type 1'].value_counts().plot(kind='pie', ax=axes[0])

pokemon_df['Type 2'].value_counts().plot(kind='pie', ax=axes[1])

axes[0].set_ylabel('')
axes[1].set_ylabel('')
fig.suptitle('Test')
plt.tight_layout()

# %%
pokemon_df['Type 1'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
