# %% [markdown]
# <h1>Numpy</h1>
#
# [Numpy](https://numpy.org/doc/stable/user/absolute_beginners.html) is a package containing a myriad of mathematical methods that can easily be implemented in your code or, at the very least, much easier than creating all those methods by hand. As the authors say, numpy is "the fundamental package for scientific computing in Python".<br>
#
# Expect to use Numpy in a daily basis for any roles that involves mathematics for example when creating simulations or processing data as numpy is incredibly powerful to process [arrays](https://www.w3schools.com/python/python_arrays.asp).<br>
#
# First let's import numpy

# %%
print('AHA!')
# Out:
# AHA!

# %%
pip install numpy
# Out:
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/6d/66/5ea5b8ef7cb3f72ecd6c905abc2331f999bf7e9de247f9db8cc9642f0eda/numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 730.4 kB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 8.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.26.3
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# How do we import a package again?
import numpy as np

# %%
np
# Out:
# <module 'numpy' from '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/__init__.py'>

# %%
# Acessing a single numpy method.
np.add
# Out:
# <ufunc 'add'>

# %%
# Using said method
np.add(2,1)
# Out:
# 3

# %% [markdown]
# It is also possible to import one specific method of a package. For example:

# %%
# Can we import only one specific method of a package?
from numpy import add

# %%
add(2,1)
# Out:
# 3

# %% [markdown]
# Is this a good idea?

# %%
add = 1

# %% [markdown]
# You can also import all the methods in a package at once:

# %%
from numpy import *

# %% [markdown]
# Question: which is the best way to import packages? Is there such a thing? <br>
#
# After answering this question let us reset the kernel and pick up from hear to clear our many definitions of numpy above.<br>
#
# Let us start by creating two arrays that we can operate with.

# %%
# Reboot the kernal and start running from here.
# Or not! But keep an eye out for possible "interferences".
import numpy as np

# %%
# To create a numpy array we pick a list and access the array method from the defined np:
test_array1 = np.array([1,2,3,4,5,6]) # The list itself is the first argument of the function.
test_array2 = np.array([2,2,2,2,2,2])

# %% [markdown]
# Question: Can you fit objects of different data types on a numpy array?

# %%
test_arrayyyyyy = np.array([1,'Cat',3,4,5,6])

# %%
test_array1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
test_arrayyyyyy
# Out:
# array(['1', 'Cat', '3', '4', '5', '6'], dtype='<U21')

# %% [markdown]
# Exercise: slice one of the arrays below to select only a subsection of its elements according to the comments.

# %%
# Here are "my" solutions:
test_a1 = np.array([1, 2, 3, 4, 5, 6])
test_a2 = np.array([2, 2, 2, 2, 2, 2])

# %%
# First element of array
print(test_a1[0])
# last element of array
print(test_a1[5])
# last 3 elements of array
print(test_a1[-3:])
# First 3.
print(test_a1[0:3])
# From index 1 to 3.
print(test_a1[1:4])
# Out:
# 1
# 6
# [4 5 6]
# [1 2 3]
# [2 3 4]

# %% [markdown]
# Let's have a look at the [documentation](https://numpy.org/doc/stable/reference/generated/numpy.array.html) of these methods and compare with what we discussed about functions. <br>
#
# Then, lets add those two arrays together and see the output.

# %%
np.add(test_a1,test_a2)
# Out:
# array([3, 4, 5, 6, 7, 8])

# %%
np.sum(test_a1)
# Out:
# 21

# %%
print(test_array1)
print(test_array2)
print(np.add(test_array1,test_array2))
# Out:
# [1 2 3 4 5 6]
# [2 2 2 2 2 2]
# [3 4 5 6 7 8]

# %% [markdown]
# Question: Can you simply use "+" to add those two arrays instead of numpy add?

# %%
test_array1+test_array2
# Out:
# array([3, 4, 5, 6, 7, 8])

# %% [markdown]
# The same can be done with 2d arrays.

# %%
test_array_2d_1 = np.array([[1,2,3],[4,5,6]])
test_array_2d_2 = np.array([[2,2,2],[2,2,2]])

# %%
print(test_array_2d_1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(test_array_2d_2)
# Out:
# [[2 2 2]
#  [2 2 2]]

# %%
np.add(test_array_2d_1, test_array_2d_2)
# Out:
# array([[3, 4, 5],
#        [6, 7, 8]])

# %%
print(np.add(test_array_2d_1, test_array_2d_2))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[2 2 2]
#  [2 2 2]]
# [[3 4 5]
#  [6 7 8]]

# %% [markdown]
# Question: How can you subtract two arrays using numpy?

# %%
np.subtract(test_array_2d_1, test_array_2d_2)
# Out:
# array([[-1,  0,  1],
#        [ 2,  3,  4]])

# %%
print(test_array_2d_1)
print(test_array_2d_2)

test_array_2d_1-test_array_2d_2
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[2 2 2]
#  [2 2 2]]
# array([[-1,  0,  1],
#        [ 2,  3,  4]])

# %%
np.add(test_array_2d_1, -1*test_array_2d_2)
# Out:
# array([[-1,  0,  1],
#        [ 2,  3,  4]])

# %% [markdown]
# Question: Will the following operation work? why?

# %%
np.add(test_array1,test_array_2d_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 np.add(test_array1,test_array_2d_1)
#
# ValueError: operands could not be broadcast together with shapes (6,) (2,3)

# %% [markdown]
# Checking the shape of an array can be done in a fairly straightforward way,

# %%
np.shape(test_array_2d_1)
# Out:
# (2, 3)

# %%
test_array_2d_1.shape
# Out:
# (2, 3)

# %% [markdown]
# Question: What will then the following operation do?

# %%
# First ask yourself what is happening here.
100 + test_array1
# Out:
# array([101, 102, 103, 104, 105, 106])

# %% [markdown]
# Arrays can also me multiplied by scalars

# %%
np.multiply(test_array1,2)
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
np.multiply(test_array1,2)*2
# Out:
# array([ 4,  8, 12, 16, 20, 24])

# %%
2*test_array1
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %% [markdown]
# Or multiplied by each other

# %%
np.multiply(test_array2,test_array1)
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
test_array2/test_array1
# Out:
# array([2.        , 1.        , 0.66666667, 0.5       , 0.4       ,
#        0.33333333])

# %%
np.multiply(test_array2,test_array_2d_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 np.multiply(test_array2,test_array_2d_1)
#
# ValueError: operands could not be broadcast together with shapes (6,) (2,3)

# %% [markdown]
# Finding where a specific information is in the array can also be incredibly useful as it allows, for example, to filter the data. One way to do this is using [numpy.where](https://numpy.org/doc/stable/reference/generated/numpy.where.html).

# %%
test_array_2d_2
# Out:
# array([[2, 2, 2],
#        [2, 2, 2]])

# %%
test_array_2d_2
np.where(test_array_2d_2)
# Out:
# (array([0, 0, 0, 1, 1, 1]), array([0, 1, 2, 0, 1, 2]))

# %%
another_array = np.array([10,20,30,40,50,60])
np.where(another_array > 30)
# Out:
# (array([3, 4, 5]),)

# %%
another_array[3] = 100

# %%
another_array
# Out:
# array([ 10,  20,  30, 100,  50,  60])

# %%
another_array[3]
# Out:
# 100

# %% [markdown]
# Question: what exatcly is the output of the function above used? How can you use it?<br>
#
# Exercise: make a 2d array similar to another_array and run np.where with a condition of your choice. What's the difference in the output?

# %%
another_array1 = np.array([[2,2,2],[1,1,1],[3,3,3]])
another_array2 = np.array([[1,2,5],[3,1,2],[2,6,1]])

# %%
np.where(another_array1 >=3)
# Out:
# (array([2, 2, 2]), array([0, 1, 2]))

# %%
indexes = np.where(another_array1 >=1)

# %%
indexes
# Out:
# (array([0, 0, 0, 1, 1, 1, 2, 2, 2]), array([0, 1, 2, 0, 1, 2, 0, 1, 2]))

# %%
indexes[0][0]
# Out:
# 0

# %%
another_array1[0,0] = 10

# %%
another_array
# Out:
# array([ 10,  20,  30, 100,  50,  60])

# %%
# An example on how to conduct an operation on the elements that satisfy the condition.
np.where(another_array > 30, another_array, another_array*10)
# Out:
# array([100, 200, 300, 100,  50,  60])

# %% [markdown]
# The dot product

# %%
np.dot(test_array_2d_1, test_array_2d_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 np.dot(test_array_2d_1, test_array_2d_2)
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
test_array_2d_3 = np.array([[1,2],[4,5],[3,6]])

# %%
np.shape(test_array_2d_3)
# Out:
# (3, 2)

# %%
np.dot(test_array_2d_1, test_array_2d_3)
# Out:
# array([[18, 30],
#        [42, 69]])

# %%
np.dot(test_array_2d_1, np.transpose(test_array_2d_2))
# Out:
# array([[12, 12],
#        [30, 30]])

# %%
np.shape(np.transpose(test_array_2d_2))
# Out:
# (3, 2)

# %%
test_array_2d_1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.transpose(test_array_2d_1)
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# There are many more operations and tools available to use in numpy and this is far from being an extensive review but just an introduction on how to use it. Which packages you will later become more familiar with will vastly depend on your field.
#
# A couple examples of applications will be discussed below.

# %%
pip install imageio
# Out:
# Collecting imageio
#   Obtaining dependency information for imageio from https://files.pythonhosted.org/packages/c0/69/3aaa69cb0748e33e644fda114c9abd3186ce369edd4fca11107e9f39c6a7/imageio-2.33.1-py3-none-any.whl.metadata
#   Downloading imageio-2.33.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from imageio) (1.26.3)
# Collecting pillow>=8.3.2 (from imageio)
#   Obtaining dependency information for pillow>=8.3.2 from https://files.pythonhosted.org/packages/37/d5/2c00228ace73a7855a52053a92fdd6cea9b22393fbf3961125c11829dcd2/pillow-10.2.0-cp312-cp312-macosx_10_10_x86_64.whl.metadata
#   Downloading pillow-10.2.0-cp312-cp312-macosx_10_10_x86_64.whl.metadata (9.7 kB)
# Downloading imageio-2.33.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 3.2 MB/s eta 0:00:0000:010:01
# Downloading pillow-10.2.0-cp312-cp312-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 5.0 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: pillow, imageio
# Successfully installed imageio-2.33.1 pillow-10.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import imageio

# %%
img = imageio.imread('Datasets/swans.jpg')
# Out:
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_70943/3575075942.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('Datasets/swans.jpg')

# %%
pwd
# Out:
# '/Users/esthersaul/Downloads/python module /Python-Module-fork'

# %%
'''values of red blue and green in an array'''

img
# Out:
# array([[[132, 109,  78],
#         [125, 102,  71],
#         [123, 100,  69],
#         ...,
#         [113, 122,  79],
#         [ 31,  43,   0],
#         [ 47,  59,  13]],
#
#        [[128, 105,  74],
#         [125, 102,  71],
#         [127, 104,  73],
#         ...,
#         [105, 117,  71],
#         [ 34,  46,   0],
#         [ 44,  57,  11]],
#
#        [[136, 113,  82],
#         [136, 113,  82],
#         [142, 119,  88],
#         ...,
#         [ 96, 109,  63],
#         [ 33,  46,   0],
#         [ 38,  54,   5]],
#
#        ...,
#
#        [[154, 151, 136],
#         [143, 140, 125],
#         [111, 107,  96],
#         ...,
#         [ 38,  62,  28],
#         [ 25,  49,  13],
#         [ 19,  45,   8]],
#
#        [[153, 150, 135],
#         [140, 137, 122],
#         [107, 103,  92],
#         ...,
#         [ 50,  74,  40],
#         [ 40,  64,  28],
#         [ 26,  52,  13]],
#
#        [[153, 150, 135],
#         [138, 135, 120],
#         [104, 100,  89],
#         ...,
#         [ 42,  66,  30],
#         [ 45,  69,  33],
#         [ 38,  64,  25]]], dtype=uint8)

# %%
np.shape(img)
# Out:
# (3000, 3000, 3)

# %%
img = imageio.imread("C:\\Users\\andre\\Documents\\Python Scripts\\Bootcamp\\Python\\Swans.jpg")
# Out:
# /var/folders/6m/w2mvnjf14415_rc8sdnfkty00000gn/T/ipykernel_70943/1590009497.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread("C:\\Users\\andre\\Documents\\Python Scripts\\Bootcamp\\Python\\Swans.jpg")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 img = imageio.imread("C:\\Users\\andre\\Documents\\Python Scripts\\Bootcamp\\Python\\Swans.jpg")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/imageio/v2.py:359, in imread(uri, format, **kwargs)
#     356 imopen_args = decypher_format_arg(format)
#     357 imopen_args["legacy_mode"] = True
# --> 359 with imopen(uri, "ri", **imopen_args) as file:
#     360     result = file.read(index=0, **kwargs)
#     362 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/imageio/core/request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/imageio/core/request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/Users/esthersaul/Downloads/python module /Python-Module-fork/C:\Users\andre\Documents\Python Scripts\Bootcamp\Python\Swans.jpg'

# %%
img
# Out:
# array([[[132, 109,  78],
#         [125, 102,  71],
#         [123, 100,  69],
#         ...,
#         [113, 122,  79],
#         [ 31,  43,   0],
#         [ 47,  59,  13]],
#
#        [[128, 105,  74],
#         [125, 102,  71],
#         [127, 104,  73],
#         ...,
#         [105, 117,  71],
#         [ 34,  46,   0],
#         [ 44,  57,  11]],
#
#        [[136, 113,  82],
#         [136, 113,  82],
#         [142, 119,  88],
#         ...,
#         [ 96, 109,  63],
#         [ 33,  46,   0],
#         [ 38,  54,   5]],
#
#        ...,
#
#        [[154, 151, 136],
#         [143, 140, 125],
#         [111, 107,  96],
#         ...,
#         [ 38,  62,  28],
#         [ 25,  49,  13],
#         [ 19,  45,   8]],
#
#        [[153, 150, 135],
#         [140, 137, 122],
#         [107, 103,  92],
#         ...,
#         [ 50,  74,  40],
#         [ 40,  64,  28],
#         [ 26,  52,  13]],
#
#        [[153, 150, 135],
#         [138, 135, 120],
#         [104, 100,  89],
#         ...,
#         [ 42,  66,  30],
#         [ 45,  69,  33],
#         [ 38,  64,  25]]], dtype=uint8)

# %%
np.shape(img)
# Out:
# (3000, 3000, 3)

# %%
pip install  matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/e4/1b/864d28d5a72d586ac137f4ca54d5afc8b869720e30d508dbd9adcce4d231/matplotlib-3.8.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata
#   Downloading matplotlib-3.8.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/4f/03/839da46999173226bead08794cbd7b4d37c9e6b02686ca74c93556b43258/contourpy-1.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading contourpy-1.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/e6/4d/c2ebaac81dadbc3fc3c3c2fa5fe7b16429dc713b1b8ace49e11e92904d78/fonttools-4.47.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading fonttools-4.47.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 2.7 MB/s eta 0:00:0000:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/2d/e0/bf8df75ba93b9e035cc6757dd5dcaf63084fdc1c846ae134e818bd7e0f03/kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/esthersaul/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp312-cp312-macosx_10_12_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 5.1 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.0-cp312-cp312-macosx_10_9_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 5.4 MB/s eta 0:00:00:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.2-cp312-cp312-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.8 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.2 kiwisolver-1.4.5 matplotlib-3.8.2 pyparsing-3.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img, origin='lower')

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[132, 109,  78],
#         [125, 102,  71],
#         [123, 100,  69],
#         ...,
#         [113, 122,  79],
#         [ 31,  43,   0],
#         [ 47,  59,  13]],
#
#        [[128, 105,  74],
#         [125, 102,  71],
#         [127, 104,  73],
#         ...,
#         [105, 117,  71],
#         [ 34,  46,   0],
#         [ 44,  57,  11]],
#
#        [[136, 113,  82],
#         [136, 113,  82],
#         [142, 119,  88],
#         ...,
#         [ 96, 109,  63],
#         [ 33,  46,   0],
#         [ 38,  54,   5]],
#
#        ...,
#
#        [[154, 151, 136],
#         [143, 140, 125],
#         [111, 107,  96],
#         ...,
#         [ 38,  62,  28],
#         [ 25,  49,  13],
#         [ 19,  45,   8]],
#
#        [[153, 150, 135],
#         [140, 137, 122],
#         [107, 103,  92],
#         ...,
#         [ 50,  74,  40],
#         [ 40,  64,  28],
#         [ 26,  52,  13]],
#
#        [[153, 150, 135],
#         [138, 135, 120],
#         [104, 100,  89],
#         ...,
#         [ 42,  66,  30],
#         [ 45,  69,  33],
#         [ 38,  64,  25]]], dtype=uint8)

# %%
np.shape(img)
# Out:
# (3000, 3000, 3)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0],cmap='hsv')

# %%
plt.imshow(img[:,:,0:1])

# %%
plt.imshow(img[:,:,0:1],cmap='gray')

# %% [markdown]
# Exercise: can you slice the picture to include only the swans?

# %%
plt.imshow(img[200:300,230:350,:])

# %% [markdown]
# Watch this [video](https://www.youtube.com/watch?v=KuXjwB4LzSA&t=572s) about convolutions. Then lets work with it!

# %%
#Ex from : https://www.kaggle.com/code/valentynsichkar/2d-image-convolution-numpy-tensorflow-keras
# Sobel filter to detect vertical changes on image
f1 = np.array([[1, 0, -1],
               [2, 0, -2],
               [1, 0, -1]])

# %%
pip install scipy
# Out:
# Collecting scipy
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/0d/4a/b2b2cae0c5dfd46361245a67102886ed7188805bdf7044e36fe838bbcf26/scipy-1.12.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata
#   Downloading scipy-1.12.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 959.9 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scipy) (1.26.3)
# Downloading scipy-1.12.0-cp312-cp312-macosx_10_9_x86_64.whl (38.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 5.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.12.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.signal import convolve2d

# %%
convolve2d(img[:,:,0],f1)
# Out:
# array([[ 132,  125,   -9, ...,  -66,  -31,  -47],
#        [ 392,  375,  -19, ..., -193,  -96, -138],
#        [ 524,  511,   -5, ..., -246, -132, -173],
#        ...,
#        [ 613,  561, -184, ...,  -71, -150, -109],
#        [ 459,  416, -144, ...,  -32, -130, -102],
#        [ 153,  138,  -49, ...,   -4,  -45,  -38]])

# %%
plt.imshow(convolve2d(img[:,:,0],f1))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
axes[0].imshow(img)
axes[1].imshow(convolve2d(img[:,:,0],f1),cmap='gray')
fig.tight_layout()
